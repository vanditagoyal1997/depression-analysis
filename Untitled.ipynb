# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.io import wavfile as wav
from scipy import signal
from python_speech_features import mfcc, logfbank
from scipy.fftpack import fft,fftfreq
import os

# %%
df1=pd.read_csv('train_split_Depression_AVEC2017.csv')
df2=pd.read_csv('300_COVAREP.csv')
df3=pd.read_csv('dev_split_Depression_AVEC2017.csv')

# %%
gaze_0=pd.read_table('300_CLNF_gaze.txt',sep=",")
gaze_1=pd.read_table('301_CLNF_gaze.txt',sep=",")
gaze_2=pd.read_table('302_CLNF_gaze.txt',sep=",")
# Out:
# C:\Users\Sankhya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\Sankhya\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#
# C:\Users\Sankhya\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
gaze_1
# Out:
#        frame   timestamp   confidence   success       x_0       y_0       z_0  \
# 0          1    0.000000     0.992054         1  0.211550  0.189897 -0.958742
# 1          2    0.033333     0.991762         1  0.224177  0.186965 -0.956446
# 2          3    0.066667     0.991636         1  0.225321  0.183741 -0.956802
# 3          4    0.100000     0.991989         1  0.233460  0.195836 -0.952442
# 4          5    0.133333     0.992227         1  0.244676  0.181430 -0.952479
# 5          6    0.166667     0.992060         1  0.237409  0.197499 -0.951121
# 6          7    0.200000     0.992038         1  0.231796  0.190426 -0.953944
# 7          8    0.233333     0.992160         1  0.240296  0.199127 -0.950056
# 8          9    0.266667     0.992166         1  0.224372  0.186050 -0.956579
# 9         10    0.300000     0.992209         1  0.223048  0.187164 -0.956671
# 10        11    0.333333     0.992195         1  0.224819  0.190533 -0.955591
# 11        12    0.366667     0.992102         1  0.214103  0.185645 -0.959008
# 12        13    0.400000     0.991992         1  0.187109  0.194127 -0.962967
# 13        14    0.433333     0.992313         1  0.213780  0.195406 -0.957139
# 14        15    0.466667     0.991745         1  0.217944  0.192935 -0.956701
# 15        16    0.500000     0.992123         1  0.215302  0.205959 -0.954581
# 16        17    0.533333     0.992047         1  0.213580  0.220313 -0.951760
# 17        18    0.566667     0.991920         1  0.203100  0.216756 -0.954865
# 18        19    0.600000     0.992131         1  0.201253  0.201725 -0.958543
# 19        20    0.633333     0.992263         1  0.206328  0.202580 -0.957283
# 20        21    0.666667     0.992178         1  0.201968  0.201305 -0.958481
# 21        22    0.700000     0.991470         1  0.194732  0.236259 -0.951978
# 22        23    0.733333     0.990789         1  0.200948  0.289029 -0.935993
# 23        24    0.766667     0.990873         1  0.199430  0.257231 -0.945547
# 24        25    0.800000     0.992111         1  0.207024  0.227374 -0.951547
# 25        26    0.833333     0.991891         1  0.203366  0.209703 -0.956382
# 26        27    0.866667     0.992166         1  0.193727  0.201434 -0.960153
# 27        28    0.900000     0.992109         1  0.191898  0.199539 -0.960916
# 28        29    0.933333     0.991758         1  0.180359  0.194637 -0.964151
# 29        30    0.966667     0.991927         1  0.166457  0.213686 -0.962616
# ...      ...         ...          ...       ...       ...       ...       ...
# 24691  24692  823.033000     0.164603         0  0.000000  0.000000 -1.000000
# 24692  24693  823.067000     0.164603         0  0.000000  0.000000 -1.000000
# 24693  24694  823.100000     0.164603         0  0.000000  0.000000 -1.000000
# 24694  24695  823.133000     0.164603         0  0.000000  0.000000 -1.000000
# 24695  24696  823.167000     0.164603         0  0.000000  0.000000 -1.000000
# 24696  24697  823.200000     0.164603         0  0.000000  0.000000 -1.000000
# 24713  0.000000 -1.000000
# 24714  0.000000 -1.000000
# 24715  0.000000 -1.000000
# 24716  0.000000 -1.000000
# 24717  0.000000 -1.000000
# 24718  0.000000 -1.000000
# 24719  0.000000 -1.000000
# 24720  0.000000 -1.000000
#
# [24721 rows x 16 columns]

# %% [markdown]
# # the difference in frames of all the three axis

# %%
s1=gaze_0[' x_h0'][1:]
s2=gaze_0[' x_h0'][:-1]
gl_x0=s2.reset_index()-s1.reset_index()
s3=gaze_0[' x_h1'][1:]
s4=gaze_0[' x_h1'][:-1]
gl_x1=s4.reset_index()-s3.reset_index()

s5=gaze_0[' y_h0'][1:]
s6=gaze_0[' y_h0'][:-1]
gl_y0=s6.reset_index()-s5.reset_index()
s7=gaze_0[' y_h1'][1:]
s8=gaze_0[' y_h1'][:-1]
gl_y1=s8.reset_index()-s7.reset_index()

s9=gaze_0[' z_h0'][1:]
s10=gaze_0[' z_h0'][:-1]
gl_z0=s10.reset_index()-s9.reset_index()
s11=gaze_0[' z_h1'][1:]
s12=gaze_0[' z_h1'][:-1]
gl_z1=s12.reset_index()-s11.reset_index()

# %%
gl_x0[gl_x0[" x_h0"]>0.001].count(),gl_x1[gl_x1[" x_h1"]>0.001].count(),gl_y0[gl_y0[" y_h0"]>0.001].count(),gl_y1[gl_y1[" y_h1"]>0.001].count(),gl_z0[gl_z0[" z_h0"]>0.001].count(),gl_z1[gl_z1[" z_h1"]>0.001].count()
# Out:
# (index    9125
#   x_h0    9125
#  dtype: int64, index    8924
#   x_h1    8924
#  dtype: int64, index    9179
#   y_h0    9179
#  dtype: int64, index    9380
#   y_h1    9380
#  dtype: int64, index    8111
#   z_h0    8111
#  dtype: int64, index    8543
#   z_h1    8543
#  dtype: int64)

# %%
s1=gaze_1[' x_h0'][1:]
s2=gaze_1[' x_h0'][:-1]
gl_x0=s2.reset_index()-s1.reset_index()
s3=gaze_1[' x_h1'][1:]
s4=gaze_1[' x_h1'][:-1]
gl_x1=s4.reset_index()-s3.reset_index()

s5=gaze_1[' y_h0'][1:]
s6=gaze_1[' y_h0'][:-1]
gl_y0=s6.reset_index()-s5.reset_index()
s7=gaze_1[' y_h1'][1:]
s8=gaze_1[' y_h1'][:-1]
gl_y1=s8.reset_index()-s7.reset_index()

s9=gaze_1[' z_h0'][1:]
s10=gaze_1[' z_h0'][:-1]
gl_z0=s10.reset_index()-s9.reset_index()
s11=gaze_1[' z_h1'][1:]
s12=gaze_1[' z_h1'][:-1]
gl_z1=s12.reset_index()-s11.reset_index()

# %%
gl_x0[gl_x0[" x_h0"]>0.001].count(),gl_x1[gl_x1[" x_h1"]>0.001].count(),gl_y0[gl_y0[" y_h0"]>0.001].count(),gl_y1[gl_y1[" y_h1"]>0.001].count(),gl_z0[gl_z0[" z_h0"]>0.001].count(),gl_z1[gl_z1[" z_h1"]>0.001].count()
# Out:
# (index    11526
#   x_h0    11526
#  dtype: int64, index    11128
#   x_h1    11128
#  dtype: int64, index    11588
#   y_h0    11588
#  dtype: int64, index    11223
#   y_h1    11223
#  dtype: int64, index    10634
#   z_h0    10634
#  dtype: int64, index    10335
#   z_h1    10335
#  dtype: int64)

# %%
s1=gaze_2[' x_h0'][1:]
s2=gaze_2[' x_h0'][:-1]
gl_x0=s2.reset_index()-s1.reset_index()
s3=gaze_2[' x_h1'][1:]
s4=gaze_2[' x_h1'][:-1]
gl_x1=s4.reset_index()-s3.reset_index()

s5=gaze_2[' y_h0'][1:]
s6=gaze_2[' y_h0'][:-1]
gl_y0=s6.reset_index()-s5.reset_index()
s7=gaze_2[' y_h1'][1:]
s8=gaze_2[' y_h1'][:-1]
gl_y1=s8.reset_index()-s7.reset_index()

s9=gaze_2[' z_h0'][1:]
s10=gaze_2[' z_h0'][:-1]
gl_z0=s10.reset_index()-s9.reset_index()
s11=gaze_2[' z_h1'][1:]
s12=gaze_2[' z_h1'][:-1]
gl_z1=s12.reset_index()-s11.reset_index()

# %%
gl_x0[gl_x0[" x_h0"]>0.001].count(),gl_x1[gl_x1[" x_h1"]>0.001].count(),gl_y0[gl_y0[" y_h0"]>0.001].count(),gl_y1[gl_y1[" y_h1"]>0.001].count(),gl_z0[gl_z0[" z_h0"]>0.001].count(),gl_z1[gl_z1[" z_h1"]>0.001].count()
# Out:
# (index    14311
#   x_h0    14311
#  dtype: int64, index    14332
#   x_h1    14332
#  dtype: int64, index    14357
#   y_h0    14357
#  dtype: int64, index    14494
#   y_h1    14494
#  dtype: int64, index    13885
#   z_h0    13885
#  dtype: int64, index    14053
#   z_h1    14053
#  dtype: int64)

# %%
# plt.plot(s3)

# plt.show()
s3=s3.abs()

# s3.describe()
a=s3[s3[" x_0"]<0.015456].count()
a
# Out:
# index    12814
#  x_0     12814
# dtype: int64

# %%
# !pip install timeside
# Out:
# Collecting timeside
#   Downloading https://files.pythonhosted.org/packages/4e/6d/d15cfb7e01e05ee7ab421f9925222f426fbc27e4933b41a8c5f36e2fba69/TimeSide-0.8.tar.gz (266kB)
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sankhya\AppData\Local\Temp\pip-install-mao7tbxp\timeside\setup.py", line 74, in <module>
#         install_requires=get_dependencies('environment.yml'),
#       File "C:\Users\Sankhya\AppData\Local\Temp\pip-install-mao7tbxp\timeside\setup.py", line 20, in get_dependencies
#         with open(env_yml_file, 'r') as f:
#     FileNotFoundError: [Errno 2] No such file or directory: 'environment.yml'
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in C:\Users\Sankhya\AppData\Local\Temp\pip-install-mao7tbxp\timeside\

# %%
import wave
import struct
import pylab
import sys
import timeside
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-80-b03565630fcc> in <module>
#       3 import pylab
#       4 import sys
# ----> 5 import timeside
#
# ModuleNotFoundError: No module named 'timeside'

# %%
def calc_fft(y,rate):
    n=len(y)
    freq = np.fft.rfftfreq(n,d=1/rate)
    mag=abs(np.fft.rfft(y)/n)
    return (mag, freq)

# %%
def plot_fft(mag):
    fig, axes = plt.subplots(nrows=2, ncols=5, sharex=False,
                             sharey=True, figsize=(20,5))
    fig.suptitle('Fourier Transforms', size=16)
    i = 0
    for x in range(2):
        for y in range(5):
            data = list(mag)[i]
            Y, freq = data[0], data[1]
#             axes[x,y].set_title(list(fft.keys())[i])
            axes[x,y].plot(freq, Y)
            axes[x,y].get_xaxis().set_visible(False)
            axes[x,y].get_yaxis().set_visible(False)
            i += 1

# %%
fs,data=wav.read('300_AUDIO.wav')
# fs1,data1=wav.read('301_AUDIO.wav')
w=wave.open('301_AUDIO.wav','rb')
# w=get_wave
# print(w.getparams())
frames = w.readframes(-1)
sound_info = pylab.fromstring(frames, 'Int16')
frame_rate = w.getframerate()
w.close()
pylab.figure(num=None, figsize=(15, 15))
pylab.subplot(111)
pylab.title('spectrogram of the audio file')
pylab.specgram(sound_info, Fs=frame_rate)
pylab.savefig('spectrogram.png')
# Out:
# C:\Users\Sankhya\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   import sys
# C:\Users\Sankhya\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   import sys

# %%
r=np.array(ret)
pri
# Out:
# array([], dtype=float64)

# %%
plt.plot(sound_info)
plt.xlabel('sample')
plt.ylabel('amplitude')
plt.show()

# %%
plt.plot(r)
plt.show()
print(fs)
# Out:
# 16000

# %%
datafft=fft(data)
# to get absolute value of the ffts
fftabs = abs(datafft)
freqs = fftfreq(fs,1/fs)
datafft[:,0]
# Out:
# array([-56.+0.j, -60.+0.j, -96.+0.j, ...,  50.+0.j,  30.+0.j,  -6.+0.j])

# %%
print(freqs.shape[0],fftabs.shape[0])
plt.plot(freqs.shape[0],fftabs.shape[0])
plt.show()
# Out:
# 16000 10376000

# %%
plt.xlim( [10, fs/2] )
plt.xscale( 'log' )
plt.grid( True )
plt.xlabel( 'Frequency (Hz)' )
plt.plot(freqs[:int(freqs.size/2)],fftabs[:int(freqs.size/2)])
# Out:
# [<matplotlib.lines.Line2D at 0x1eafc844630>,
#  <matplotlib.lines.Line2D at 0x1eafc86b7b8>]

# %%
os.chdir('E:/final year project')
os.chdir('E:/final year project/Audio')
f=os.listdir()

# %%
os.getcwd()
# Out:
# 'E:\\final year project\\Audio'

# %%
a=os.listdir()

for i in a:
    w=wave.open(i,'rb')
    frames = w.readframes(-1)
    sound_info = pylab.fromstring(frames, 'Int16')
    frame_rate = w.getframerate()
    w.close()
    pylab.figure(num=None, figsize=(513, 125))
    pylab.subplot(111)
    pylab.title('spectrogram of the audio file')
    pylab.specgram(sound_info, Fs=frame_rate)
#     pylab.savefig('spectrogram.png')
    pylab.savefig('E:/final year project/Spectrogram/'+i[0:-3]+'spec.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a67396c81eae> in <module>
#       2
#       3 for i in a:
# ----> 4     w=wave.open(i,'rb')
#       5     frames = w.readframes(-1)
#       6     sound_info = pylab.fromstring(frames, 'Int16')
#
# NameError: name 'wave' is not defined

# %% [markdown]
# # convolution network for audio processing

# %%
from keras.models import Sequential
import keras
from keras.layers import Dense, Conv2D, Flatten,MaxPooling2D,Dropout
from keras.datasets import mnist
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
num_classes=2
y=[]

# %%
# (x_train, y_train), (x_test, y_test) = mnist.load_data()
# y_train.shape
x.shape
# Out:
# (1080, 1080, 3)

# %%
os.chdir('E:/final year project/Spectrogram')
a=os.listdir()
arr=[]
for i in a:
    t=load_img(i)
    x=img_to_array(t)
#     x = x.reshape((1,) + x.shape)
    arr.append(x)
# np.array(arr,dtype=np.float32)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 1078, 1078, 32)    896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 539, 539, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 537, 537, 64)      18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 268, 268, 64)      0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4596736)           0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               -194143795
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: -1,941,154,878
# Trainable params: -1,941,154,878
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=(1080,1080,3)))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid', data_format=None))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])

# %%
model.fit(arr, y,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
